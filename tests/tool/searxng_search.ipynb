# %%
# %run ../init.ipynb

from chatgpt_tool_hub.tools import dynamic_tool_loader
from chatgpt_tool_hub.tools.all_tool_list import main_tool_register

# 尽可能地加载tool
dynamic_tool_loader()

_func, _ = main_tool_register.get_registered_tool()['searxng-search']
# Out:
# /Users/goldfish/VSCode/chatgpt-tool-hub
# chatgpt-tool-hub version: 0.5.0
# [INFO][2024-01-09 00:15:53][__init__.py:29] - [visual_dl] init failed, error_info: ModuleNotFoundError("No module named 'torch'")

# %%
"""debug mode"""

tool = _func(searxng_search_debug=True)
result_list = []
result_list.append(tool.run("mixtral模型的作者是谁？"))
result_list.append(tool.run("这周末想去北京周边徒步，推荐我一些地点？"))
result_list.append(tool.run("番茄炒蛋的步骤有哪些？"))
result_list.append(tool.run("如何治疗荨麻疹？"))
result_list.append(tool.run("最近有哪些新电影？"))
result_list.append(tool.run("S13冠军是哪个战队？"))

for result in result_list: print(result)
# Out:
# [INFO][2024-01-08 23:53:01][chatgpt.py:186] - proxy no find, directly request to chatgpt instead
# [DEBUG][2024-01-08 23:53:01][chatgpt.py:196] - success use llm api key: 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
# [DEBUG][2024-01-08 23:53:02][tool.py:42] - [searxng-search]: search_query: {'input': 'mixtral模型的作者是谁？', 'text': 'mixtral 模型 作者'}
# [DEBUG][2024-01-08 23:53:04][tool.py:42] - [searxng-search]: search_query: {'input': '这周末想去北京周边徒步，推荐我一些地点？', 'text': '北京周边 徒步 地点 推荐'}
# [DEBUG][2024-01-08 23:53:05][tool.py:42] - [searxng-search]: search_query: {'input': '番茄炒蛋的步骤有哪些？', 'text': '番茄炒蛋 步骤'}
# [DEBUG][2024-01-08 23:53:07][tool.py:42] - [searxng-search]: search_query: {'input': '如何治疗荨麻疹？', 'text': '治疗 荨麻疹'}
# [DEBUG][2024-01-08 23:53:08][tool.py:42] - [searxng-search]: search_query: {'input': '最近有哪些新电影？', 'text': '新电影'}
# [DEBUG][2024-01-08 23:53:09][tool.py:42] - [searxng-search]: search_query: {'input': 'S13冠军是哪个战队？', 'text': 'S13 冠军 战队'}
# {'input': 'mixtral模型的作者是谁？', 'text': 'mixtral 模型 作者'}
# {'input': '这周末想去北京周边徒步，推荐我一些地点？', 'text': '北京周边 徒步 地点 推荐'}
# {'input': '番茄炒蛋的步骤有哪些？', 'text': '番茄炒蛋 步骤'}
# {'input': '如何治疗荨麻疹？', 'text': '治疗 荨麻疹'}
# {'input': '最近有哪些新电影？', 'text': '新电影'}
# {'input': 'S13冠军是哪个战队？', 'text': 'S13 冠军 战队'}

# %%
"""test searxng api"""
from chatgpt_tool_hub.tools.searxng_search.wrapper import SearxSearchWrapper

wrapper = SearxSearchWrapper(searx_search_top_k_results=3)
result = wrapper.run("mixtral 模型 作者")
print(result)
result = wrapper.run("北京周边 徒步 地点 推荐")
print(result)
result = wrapper.run("番茄炒蛋 步骤")
print(result)
result = wrapper.run("治疗 荨麻疹")
print(result)
result = wrapper.run("新电影")
print(result)
result = wrapper.run("S13 冠军 战队")
print(result)
# Out:
# 本次发布的 Mixtral 模型的主要特点: 模型包括基础版和指令版 支持高达 32k 词元的上下文 性能优于 Llama 2 70B，在大多数基准测试上表现不逊于 GPT3.5 支持英语、法语、德语、西班牙语及意大利语 擅长编码，HumanEval 得分为 40.2% 可商用，Apache 2.0 许可证 那么，Mixtral 模型效果到底有多好呢？ 下面列出了 Mixtral 基础模型与其他先进的开放模型在 LLM 排行榜 上表现 (分数越高越好): 我们还用 MT-Bench 及 AlpacaEval 等基准对指令版和其它聊天模型进行了对比。 下表列出了 Mixtral Instruct 与顶级闭源或开放模型相比的表现 (分数越高越好):
#
# Mixtral-8x7B 是一款混合专家模型（Mixtrue of Experts），由8个拥有70亿参数的专家网络组成，在能力上，Mixtral-8x7B 支持32k token 上下文长度，支持英语、法语、意大利语、德语和西班牙语，拥有优秀的代码生成能力，可微调为指令跟随模型。
#
# 4天前 — ... ，Mistral 发布了一个激动人心的大语言模型: Mixtral 8x7b，该模型把开放模型的性能带到了一个新高度，并在许多基准测试上表现优于GPT ... 原文作者: Lewis ...
# NO1.香八拉 香巴拉是藏语的音译，又译为香格里拉，意思是 极乐园 ，北京驴友口口相传的香八拉即香山邮局到八大处公园的拉练，是北京近郊公交出行最经典的户外徒步路线，没有之一。 里程：14KM，预计6h可完成 交通：地铁公交出行，导航香山站 参考轨迹号：#2658192 NO2.三峰连穿 三峰是北京近郊除香八拉之外，最为经典的户外拉练路线，自大觉寺起经阳台山-妙峰山，再返回大觉寺的环穿路线，非常适合拉练。 里程：23KM，预计10h可完成 交通：地铁公交出行，导航大觉寺站 参考轨迹号：#2912483 NO3.京西古道 京西古道是指北京西部山区的古代交通道路，深得户外爱好者们的青睐，此线路难度强度不大，适合周末休闲徒步，风景秀丽，古韵足迹浓厚。 里程：20KM，预计7h可完成
#
# 1、箭扣长城--寻找心中的长城. 来到北京，所有人第一时间想到的绝对是八达岭长城，但是除了八达岭还有一个最经典长城，箭扣! 从西栅子村起程，沿明显的小路可以分别从几处登上长城，九眼楼、北京结、天梯，鹰飞倒仰，可以说是箭扣长城的精华所在! 箭扣长城，危险，因为它有些地方，基本接近垂直的角度，而且是没有经过修复的长城，箭扣长城，美，因为它在大山深处，长城两边都是各种红叶，每到秋季，箭扣长城也是北京周边最佳的赏红叶的观赏点。 所以如果你有时间，一定要去登一次箭扣! 但是去的时候要找一个好的队伍，因为箭扣长城是北京户外圈里，最易出事故的地段! 2、小五台山（西灵山）穿越. 小五台有两个比较重要的入口：西面的西金河口和北面的赤崖堡村。
#
# Hello~旅游小小值上一次推荐了江浙沪皖周边徒步线路，值友们收藏踊跃，有值友说能不能出一篇京津冀的周边，好的，今天先安排上北京周边。 小编带你玩 篇二十：约上小姐姐徒步去! 这13个江浙沪皖周边线路，人少景美! 速速收藏! 大家好，我是旅游小小值~昨天给大家深夜放了一波扬州美食，今天给大家种草一波江浙沪皖周边游徒步线路，疫情结束后，约上小姐姐，玩儿去! 这些线路的优点是路途近，开车自驾就能去，无需过早策划，疫情结束之后就能说走就走；景区开阔，不少是户外爱好者开拓出来的徒步线路，人少景美，助力于放松身心。 像钟南山院士所说： 旅游小小值 | 赞572 评论180 收藏7k 查看详情. 等国内疫情稳定了，从安全系数最高的周边开始游起来。 适当活动，逐渐增加运动强度，有益身心健康。
# 将西红柿洗干净后，用刚烧开的水烫一下，去皮、去蒂、切片，放到一边待用。 将鸡蛋打入碗中，加适量盐，然后用筷子充分搅打均匀待用。 在炒锅里放油，用大火烧热后，将鸡蛋迅速放入锅中炒熟，轻轻搅烂后盛出。 将剩余的油烧热，下西红柿片煸炒，放盐、糖炒片刻，再倒入已炒好的鸡蛋翻炒几下，混合均匀后出锅即成。
# 2023年10月27日 — 止痒药。荨麻疹和血管性水肿的标准治疗方案是使用不会使人感到困倦的抗组胺药。这些药物可以减轻瘙痒、肿胀和其他过敏症状。有处方药和非处方药两种。
#
# 阅读更多 治疗荨麻疹。这些治疗性药物会部分缓解瘙痒和消肿。为了确保疗效，必须定期服用，而不是仅在需要时服用。一些抗组胺药，包括西替利嗪、苯海拉明、氯雷他定，无需处方即可购买。苯海拉明是一种较老的抗组胺药，比其他两种药物更可能引起
#
#
# 即将上映电影 ; 01月12日, 大雨, 动画/ 奇幻/ 冒险 ; 01月12日, 夜幕将至, 剧情/ 爱情 ; 01月12日, 养蜂人, 动作/ 惊悚 ; 01月12日, 你的约定, 爱情 ...
#
# 最新上映的新片,零度极限,潜行,年会不能停！,金色面具英雄,金手指,一闪一闪亮星星,舒克贝塔·五角飞碟,非诚勿扰3,你的婚礼,泰勒·斯威夫特：时代巡回演唱会,寒单, ...
#
#
# 2023年11月19日 — 在北京时间11 月19 日16 点开赛的《英雄联盟》S13 全球总决赛冠军中，来自韩国战区的T1 战队以3 比0 的比分轻松战胜了来自中国大陆赛区的WBG 战队， ...
#
#
#
# 4天前 — 1、英雄联盟S13全球总决赛决赛于11月19日进行，参赛队伍是LPL赛区的WBG战队对阵LCK赛区的T1战队; · 2、T1战队3：0战胜WBG战队获得S13世界赛冠军，第一局WBG ...

# %%
"""normal test"""
tool = _func()
result = tool.run("mixtral模型的作者是谁？")
print(result)
# Out:
# [INFO][2024-01-09 00:15:57][chatgpt.py:186] - proxy no find, directly request to chatgpt instead
# [DEBUG][2024-01-09 00:15:57][chatgpt.py:196] - success use llm api key: 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
# [DEBUG][2024-01-09 00:15:59][tool.py:43] - [searxng-search]: search_query: {'input': 'mixtral模型的作者是谁？', 'text': 'mixtral 模型 作者'}
# [DEBUG][2024-01-09 00:16:01][wrapper.py:276] - [searxng-search] output: [{'title': '欢迎 Mixtral - 当前 Hugging Face 上最先进的 MoE 模型 - 知乎', 'url': 'https://zhuanlan.zhihu.com/p/676010571', 'content': '本次发布的 Mixtral 模型的主要特点: 模型包括基础版和指令版 支持高达 32k 词元的上下文 性能优于 Llama 2 70B，在大多数基准测试上表现不逊于 GPT3.5 支持英语、法语、德语、西班牙语及意大利语 擅长编码，HumanEval 得分为 40.2% 可商用，Apache 2.0 许可证 那么，Mixtral 模型效果到底有多好呢？ 下面列出了 Mixtral 基础模型与其他先进的开放模型在 LLM 排行榜 上表现 (分数越高越好): 我们还用 MT-Bench 及 AlpacaEval 等基准对指令版和其它聊天模型进行了对比。 下表列出了 Mixtral Instruct 与顶级闭源或开放模型相比的表现 (分数越高越好):', 'engine': 'qwant', 'parsed_url': ['https', 'zhuanlan.zhihu.com', '/p/676010571', '', '', ''], 'template': 'default.html', 'engines': ['qwant', 'google', 'duckduckgo'], 'positions': [1, 4, 1], 'img_src': None, 'score': 6.75, 'category': 'general'}, {'url': 'https://www.oschina.net/news/270317/mixtral-8x7b-32kseqlen', 'title': 'Mistral AI 用「磁链链接」开源了 87 GB 的 8x7B MoE 模型 - OSCHINA - 中文开源技术交流社区', 'content': '', 'img_src': '', 'engine': 'brave', 'parsed_url': ['https', 'www.oschina.net', '/news/270317/mixtral-8x7b-32kseqlen', '', '', ''], 'template': 'default.html', 'engines': ['brave'], 'positions': [1], 'score': 1.0, 'category': 'general'}, {'url': 'https://www.cnblogs.com/huggingface/p/17944988', 'title': '欢迎Mixtral - 当前Hugging Face 上最先进的MoE 模型', 'content': '4天前 — ... ，Mistral 发布了一个激动人心的大语言模型: Mixtral 8x7b，该模型把开放模型的性能带到了一个新高度，并在许多基准测试上表现优于GPT ... 原文作者: Lewis ...', 'img_src': None, 'engine': 'google', 'parsed_url': ['https', 'www.cnblogs.com', '/huggingface/p/17944988', '', '', ''], 'template': 'default.html', 'engines': ['google'], 'positions': [1], 'score': 1.0, 'category': 'general'}, {'url': 'https://www.xujun.org/note-168164.html', 'title': '开源 MoE 模型 Mixtral 8x7B 性能超过 GPT-3.5-低调大师', 'content': '', 'img_src': '', 'engine': 'brave', 'parsed_url': ['https', 'www.xujun.org', '/note-168164.html', '', '', ''], 'template': 'default.html', 'engines': ['brave'], 'positions': [2], 'score': 0.5, 'category': 'general'}, {'url': 'https://101.dev/t/mixtral-hugging-face-moe/1210', 'title': '欢迎Mixtral - 当前Hugging Face 上最先进的MoE 模型', 'content': '4天前 — ... ，Mistral 发布了一个激动人心的大语言模型: Mixtral 8x7b，该模型把开放模型的性能带到了一个新高度，并在许多基准测试上表现优于GPT ... 原文作者: Lewis ...', 'img_src': None, 'engine': 'google', 'parsed_url': ['https', '101.dev', '/t/mixtral-hugging-face-moe/1210', '', '', ''], 'template': 'default.html', 'engines': ['google'], 'positions': [2], 'score': 0.5, 'category': 'general'}, {'url': 'https://www.unite.ai/zh-CN/Mistral-ais-最新专家混合模型-moe-8x7b-模型/', 'title': 'Mistral AI 的最新专家混合(MoE) 8x7B 模型', 'content': '', 'img_src': '', 'engine': 'brave', 'parsed_url': ['https', 'www.unite.ai', '/zh-CN/Mistral-ais-最新专家混合模型-moe-8x7b-模型/', '', '', ''], 'template': 'default.html', 'engines': ['brave'], 'positions': [3], 'score': 0.3333333333333333, 'category': 'general'}, {'url': 'https://hub.baai.ac.cn/view/34072', 'title': '欢迎Mixtral - 当前Hugging Face 上最先进的MoE 模型', 'content': '4天前 — 宝子们可以戳阅读原文查看文中所有的外部链接哟！ 英文原文: https://hf.co/blog/mixtral. 原文作者: Lewis Tunstall，Philipp Schmid ...', 'img_src': None, 'engine': 'google', 'parsed_url': ['https', 'hub.baai.ac.cn', '/view/34072', '', '', ''], 'template': 'default.html', 'engines': ['google'], 'positions': [3], 'score': 0.3333333333333333, 'category': 'general'}, {'url': 'https://zhuanlan.zhihu.com/p/674751021', 'title': 'Mixtral-8x7B 模型挖坑', 'content': 'MistralAI很高冷的给开源社区扔了一条磁力链，基于Mixture of Experts的混合专家模型 Mixtral-8x7B 和指令微调的 Mixtral-8x7B-Instruct 来了。 此前曾爆料GPT4就是基于MoE技术的大模型，MistralAI证明通过不到8个7B的参数量，不到2个7B模型的计算量，就能超越LLaMA 2 70B的效果，甚至部分超越了GPT-3.5的水平，随即这两个模型引爆社交网络。 截至目前， 官网 展示了Mixtral-8x7B的模型效果： 图1. Mistral 8x7B超越LLaMA 2 70B和GPT-3.5', 'img_src': None, 'engine': 'google', 'parsed_url': ['https', 'zhuanlan.zhihu.com', '/p/674751021', '', '', ''], 'template': 'default.html', 'engines': ['google', 'duckduckgo'], 'positions': [9, 23], 'score': 0.30917874396135264, 'category': 'general'}, {'url': 'https://www.zhihu.com/question/319773766', 'title': '哪些网站可以免费下载3D模型，求推荐？ - 知乎', 'content': '', 'img_src': '', 'engine': 'b ...
# 《欢迎 Mixtral - 当前 Hugging Face 上最先进的 MoE 模型 - 知乎》
# 本次发布的 Mixtral 模型的主要特点: 模型包括基础版和指令版 支持高达 32k 词元的上下文 性能优于 Llama 2 70B，在大多数基准测试上表现不逊于 GPT3.5 支持英语、法语、德语、西班牙语及意大利语 擅长编码，HumanEval 得分为 40.2% 可商用，Apache 2.0 许可证 那么，Mixtral 模型效果到底有多好呢？ 下面列出了 Mixtral 基础模型与其他先进的开放模型在 LLM 排行榜 上表现 (分数越高越好): 我们还用 MT-Bench 及 AlpacaEval 等基准对指令版和其它聊天模型进行了对比。 下表列出了 Mixtral Instruct 与顶级闭源或开放模型相比的表现 (分数越高越好):
# [https://zhuanlan.zhihu.com/p/676010571]
#
# ---
#
# 《Mistral AI 用「磁链链接」开源了 87 GB 的 8x7B MoE 模型 - OSCHINA - 中文开源技术交流社区》
#
# [https://www.oschina.net/news/270317/mixtral-8x7b-32kseqlen]
#
# ---

# %%
"""output_type = json"""
tool = _func(searx_search_output_type="json")
result = tool.run("S13冠军是哪个战队？")
print(result)
# Out:
# [INFO][2024-01-09 00:16:21][chatgpt.py:186] - proxy no find, directly request to chatgpt instead
# [DEBUG][2024-01-09 00:16:25][tool.py:43] - [searxng-search]: search_query: {'input': 'S13冠军是哪个战队？', 'text': 'S13 冠军 战队'}
# [DEBUG][2024-01-09 00:16:28][wrapper.py:379] - [searxng-search] output: [{'url': 'https://www.gcores.com/articles/173984', 'title': 'T1轻取WBG,斩获《英雄联盟》S13总决赛冠军', 'content': '2023年11月19日 — 在北京时间11 月19 日16 点开赛的《英雄联盟》S13 全球总决赛冠军中，来自韩国战区的T1 战队以3 比0 的比分轻松战胜了来自中国大陆赛区的WBG 战队， ...', 'img_src': None, 'engine': 'google', 'parsed_url': ['https', 'www.gcores.com', '/articles/173984', '', '', ''], 'template': 'default.html', 'engines': ['google'], 'positions': [1], 'score': 1.0, 'category': 'general'}, {'url': 'https://m.clinicmed.net/article/20478.html', 'title': 'lol全球总决赛赛程-2023英雄联盟全球总决赛赛程表-沧浪手游', 'content': '', 'img_src': '', 'engine': 'brave', 'parsed_url': ['https', 'm.clinicmed.net', '/article/20478.html', '', '', ''], 'template': 'default.html', 'engines': ['brave'], 'positions': [1], 'score': 1.0, 'category': 'general'}, {'url': 'https://m.yanlutong.com/xinwen/1955.html', 'title': '英雄联盟s13冠军是哪个战队 - 燕鹿手游', 'content': '2023年11月20日 — 英雄联盟s13已经落下帷幕，不少没看决赛的玩家还不清楚英雄联盟s13冠军是哪个战队，s13冠军是来自韩国LCK赛区的T1，以3比0战胜WBG拿下冠军。, ...', 'img_src': None, 'engine': 'google', 'parsed_url': ['https', 'm.yanlutong.com', '/xinwen/1955.html', '', '', ''], 'template': 'default.html', 'engines': ['google'], 'positions': [2], 'score': 0.5, 'category': 'general'}, {'url': 'https://m.cehca.com/sjxw/10271.html', 'title': 's13全球总决赛赛程表-英雄联盟s13全球总决赛赛程一览-CC手游网', 'content': '', 'img_src': '', 'engine': 'brave', 'parsed_url': ['https', 'm.cehca.com', '/sjxw/10271.html', '', '', ''], 'template': 'default.html', 'engines': ['brave'], 'positions':